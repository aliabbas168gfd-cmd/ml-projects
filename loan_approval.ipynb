# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
df=pd.read_csv("loan.csv")

# %%
c=df.dropna()

# %%
df.groupby(["Loan_Term"]).agg({"Loan_Term":"count"})
# Out:
#            Loan_Term
# Loan_Term
# 12.0             142
# 24.0             135
# 36.0             122
# 48.0             148
# 60.0             131
# 72.0             129
# 84.0             143

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Applicant_ID        1000 non-null   int64
#  1   Applicant_Income    1000 non-null   float64
#  2   Coapplicant_Income  1000 non-null   float64
#  3   Employment_Status   1000 non-null   object
#  4   Age                 1000 non-null   float64
#  5   Marital_Status      1000 non-null   object
#  6   Dependents          1000 non-null   float64
#  7   Credit_Score        1000 non-null   float64
#  8   Existing_Loans      1000 non-null   float64
#  9   DTI_Ratio           1000 non-null   float64
#  10  Savings             1000 non-null   float64
#  11  Collateral_Value    1000 non-null   float64
#  12  Loan_Amount         1000 non-null   float64
#  13  Loan_Term           1000 non-null   float64
#  14  Loan_Purpose        1000 non-null   object
# ...

# %%
df.describe()
# Out:
#        Applicant_ID  Applicant_Income  Coapplicant_Income         Age  \
# count    950.000000        950.000000          950.000000  950.000000
# mean     501.220000      10852.571579         5082.455789   39.971579
# std      289.608451       5061.632859         2943.161570   11.139797
# min        1.000000       2009.000000            1.000000   21.000000
# 25%      250.250000       6730.750000         2472.750000   30.250000
# 50%      499.500000      10548.000000         5205.500000   40.000000
# 75%      752.750000      15190.000000         7620.750000   49.000000
# max     1000.000000      19988.000000         9996.000000   59.000000
#
#        Dependents  Credit_Score  Existing_Loans   DTI_Ratio       Savings  \
# count  950.000000    950.000000      950.000000  950.000000    950.000000
# mean     1.474737    676.033684        1.950526    0.347263   9940.452632
# std      1.105067     71.346015        1.406246    0.144341   5860.736885
# ...

# %%
df["Applicant_ID"]=df.index+1

# %%
df["Loan_Purpose"]=df["Loan_Purpose"].bfill()

# %%
df["Loan_Purpose"]=df["Loan_Purpose"].bfill()

# %%
df["Education_Level"]=df["Education_Level"].bfill()

# %%
df["Gender"]=df["Gender"].ffill()

# %%
df["Employer_Category"]=df["Employer_Category"].bfill()

# %%
df["Applicant_Income"]=df["Applicant_Income"].fillna(10852.571579)

# %%
df["Coapplicant_Income"]=df["Coapplicant_Income"].fillna(5082.455789)

# %%
df["Employment_Status"]=df["Employment_Status"].fillna("Salaried")

# %%
df["Age"]=df["Age"].fillna(39)

# %%
df["Marital_Status"]=df["Marital_Status"].fillna("Married")

# %%
df["Dependents"]=df["Dependents"].fillna(0)

# %%
df["Credit_Score"]=df["Credit_Score"].fillna(676.033684)

# %%
df["Existing_Loans"]=df["Existing_Loans"].fillna(1)

# %%
df["DTI_Ratio"]=df["DTI_Ratio"].fillna(0.347263)

# %%
df["Savings"]=df["Savings"].fillna(9940.452632)

# %%
df["Collateral_Value"]=df["Collateral_Value"].fillna(24802.792632)

# %%
df["Loan_Amount"]=df["Loan_Amount"].fillna(20522.825263)

# %%
df["Loan_Approved"]=df["Loan_Approved"].fillna(0)

# %%
df["Loan_Term"]=df["Loan_Term"].fillna(48)

# %%
df["Loan_Approved"]=df["Loan_Approved"].map({"Yes":1,"No":0})

# %%
df.corr(numeric_only=True)["Loan_Approved"].sort_values()
# Out:
# DTI_Ratio            -0.472434
# Loan_Amount          -0.130477
# Loan_Term            -0.092600
# Existing_Loans       -0.036184
# Age                  -0.028058
# Savings              -0.017319
# Dependents           -0.016541
# Applicant_ID         -0.005508
# Coapplicant_Income    0.009340
# Collateral_Value      0.028128
# Applicant_Income      0.127922
# Credit_Score          0.489880
# Loan_Approved         1.000000
# Name: Loan_Approved, dtype: float64

# %%
le=LabelEncoder()
df["Gender"]=le.fit_transform(df["Gender"])
df["Marital_Status"]=le.fit_transform(df["Marital_Status"])
df["Property_Area"]=le.fit_transform(df["Property_Area"])
df["Education_Level"]=le.fit_transform(df["Education_Level"])
df["Employer_Category"]=le.fit_transform(df["Employer_Category"])
df["Employer_Category"]=le.fit_transform(df["Employer_Category"])
df["Loan_Purpose"]=le.fit_transform(df["Loan_Purpose"])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score

# %%
X=c.drop("Loan_Approved",axis=1)
y=c["Loan_Approved"]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=31)

# %%
ss=StandardScaler()
X_trains=ss.fit_transform(X_train)
X_tests=ss.transform(X_test)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)
a=accuracy_score(y_test,y_pred)
p=precision_score(y_test,y_pred)
print(a)
print(p)
# Out:
# 0.8315789473684211
# 0.7096774193548387

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=9)
knn.fit(X_trains,y_train)
y_pred=knn.predict(X_tests)
a1=accuracy_score(y_test,y_pred)
p1=precision_score(y_test,y_pred)
print(a1)
print(p1)
# Out:
# 0.8052631578947368
# 0.6981132075471698

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_trains,y_train)
y_pred=nb.predict(X_tests)
a1=accuracy_score(y_test,y_pred)
p1=precision_score(y_test,y_pred)
print(a1)
print(p1)
# Out:
# 0.8421052631578947
# 0.78

# %%
df.sample(20)
# Out:
#      Applicant_ID  Applicant_Income  Coapplicant_Income  Employment_Status  \
# 163           164       3930.000000              5468.0                  2
# 498           499      15428.000000              2356.0                  1
# 330           331       7177.000000              7491.0                  0
# 404           405      13338.000000              2946.0                  2
# 999          1000      13093.000000              2385.0                  1
# 970           971      17149.000000              9011.0                  0
# 618           619       7569.000000              9400.0                  1
# 749           750      14819.000000              5047.0                  3
# 72             73      18216.000000              7101.0                  1
# 706           707      14199.000000              4760.0                  1
# 406           407       9543.000000               526.0                  2
# ...
